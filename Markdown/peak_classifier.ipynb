# %%
import pandas as pd

# %%
data = pd.read_csv("K:/shares/di04_limet_bioinformatics/PhD Pablo/Publicaties/WIP/TARDIS/data/metabease_metabolomics/positive/feature_table.csv")

# %%
data = data[["AUC","MaxInt","SNR","peak_cor","rating"]]

# %%
data["rating"] = data["rating"].replace('Ambiguous', 'Bad')

# %%
data
# Out:
#               AUC        MaxInt       SNR  peak_cor rating
# 0    3.084307e+07  8.481991e+06  3.550055  0.694646    Bad
# 1    3.956869e+05  1.926466e+05  1.886264  0.235033    Bad
# 2    1.457238e+06  3.261266e+05  1.233778  0.540412    Bad
# 3    2.140362e+06  4.587443e+05  4.770393  0.787729    Bad
# 4    5.480646e+04  4.697291e+04  1.947350  0.696860    Bad
# ..            ...           ...       ...       ...    ...
# 227  1.671162e+06  4.748121e+05  4.817646  0.632349   Good
# 228  1.650037e+06  3.080719e+05  2.480406  0.651770    Bad
# 229  2.278465e+06  6.078775e+05  4.118879  0.647585    Bad
# 230  1.322349e+07  1.858222e+06  7.184562  0.603882    Bad
# 231  3.247844e+07  1.835489e+07  3.236626  0.855786   Good
#
# [232 rows x 5 columns]

# %%
data["rating"].value_counts()
# Out:
# Good    143
# Bad      89
# Name: rating, dtype: int64

# %%
from pycaret.classification import *
s = setup(data, target = 'rating', session_id = 123,train_size = 0.8)
# Out:
# <style type="text/css">
# #T_985d3_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_985d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_985d3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_985d3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_985d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_985d3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_985d3_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_985d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_985d3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_985d3_row1_col1" class="data row1 col1" >rating</td>
#     </tr>
#     <tr>
#       <th id="T_985d3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6d7ee th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot='feature')
